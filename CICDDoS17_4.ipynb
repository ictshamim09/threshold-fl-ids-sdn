# %%
#!/usr/bin/env python3

import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score,
    f1_score, matthews_corrcoef, cohen_kappa_score,
    log_loss, balanced_accuracy_score
)
import true_threshold_ckks
import os
import time
import csv
import hashlib
import pickle
from typing import List, Dict, Tuple, Optional
import random
import tempfile


# ===============================
# Hash Utility Functions
# ===============================
def compute_hash(data: bytes) -> str:
    return hashlib.sha256(data).hexdigest()


def verify_hash(data: bytes, expected_hash: str) -> bool:
    return compute_hash(data) == expected_hash


# ===============================
# DKG-based TRUE Threshold HE Manager Wrapper
#
# Key difference from the original:
#   Original  → C++ KeyGen() produces one master keypair; Shamir splits the
#               single master secret.  The full secret EXISTS in one place.
#
#   DKG version → Each party independently samples its own secret s_i.
#                 The public key pk = Σ pk_i is assembled without any party
#                 ever seeing the combined secret s = Σ s_i.
#                 Threshold decryption still uses Lagrange interpolation over
#                 Shamir shares — but those shares come from each party's
#                 *own* s_i, not from a centralised secret.
#
# DKG Protocol (3 phases, all driven from Python):
#   Phase 1 – Secret generation : each party i calls dkg_generate_party_secret(i)
#   Phase 2 – Key aggregation   : collect pk_i bytes, call dkg_finalize_public_key()
#   Phase 3 – Shamir sharing    : generate_key_shares() now splits each party's
#                                 own s_i; combined shares are handed to
#                                 construct_party_key() as before.
# ===============================
class TrueThresholdCKKSWrapper:
    def __init__(self, num_parties: int, threshold: int, ring_dim: int = 8192,
                 batch_size: int = 4096, mult_depth: int = 10, scale_bits: int = 50):
        self.num_parties = num_parties
        self.threshold   = threshold
        self.batch_size  = batch_size
        self.ring_dim    = ring_dim

        print(f"[HE Manager] Initialising DKG-based TRUE threshold CKKS")
        print(f"  Threshold : {threshold}-of-{num_parties}")
        print(f"  Ring dim  : {ring_dim},  Batch size: {batch_size}")

        self.ckks = true_threshold_ckks.TrueThresholdCKKS(
            num_parties = num_parties,
            threshold   = threshold,
            ring_dim    = ring_dim,
            batch_size  = batch_size,
            mult_depth  = mult_depth,
            scale_bits  = scale_bits
        )

        # ── Phase 1: chain-based DKG key generation ─────────────────────────
        print(f"\n[HE Manager] DKG Phase 1 – chain key generation")
        # Party 1 is lead
        pk_bytes = self.ckks.dkg_lead_keygen()
        print(f"  Party 1 (lead) done")
        # Parties 2..n join the chain sequentially
        for party_id in range(2, num_parties + 1):
            pk_bytes = self.ckks.dkg_join_keygen(party_id, pk_bytes)
            print(f"  Party {party_id} (join) done")

        # ── Phase 2: finalize joint public key ───────────────────────────────
        # The last party's chained pk IS the joint pk
        print(f"\n[HE Manager] DKG Phase 2 – finalizing joint public key")
        self.ckks.dkg_finalize_public_key(pk_bytes)
        print(f"[HE Manager] Joint pk ready — combined secret was NEVER assembled")

        # ── Phase 3: EvalMult collaborative keygen ───────────────────────────
        print(f"\n[HE Manager] DKG Phase 3 – collaborative EvalMult key")
        eval_bytes = self.ckks.dkg_evalmult_keygen(1)
        for party_id in range(2, num_parties + 1):
            eval_bytes = self.ckks.dkg_evalmult_join(party_id, eval_bytes)
        self.ckks.dkg_evalmult_finalize(eval_bytes)
        print(f"[HE Manager] EvalMult key ready")

        # ── Phase 4: Shamir backup shares (key recovery / threshold decrypt) ─
        print(f"\n[HE Manager] DKG Phase 4 – Shamir backup shares")
        # Each party i splits its own s_i into (t,n) shares
        # Party j's combined share = sum of share_i(j) for all i
        # We simulate this by summing across parties per recipient
        combined_shares = {}   # recipient_id -> combined share coeffs

        for party_id in range(1, num_parties + 1):
            shares = self.ckks.generate_key_shares(
                party_id, threshold, num_parties)
            for recipient_idx in range(num_parties):
                recipient_id = recipient_idx + 1
                if recipient_id not in combined_shares:
                    combined_shares[recipient_id] = np.zeros(
                        len(shares[recipient_idx]), dtype=np.int64)
                combined_shares[recipient_id] += shares[recipient_idx]

        # Register each party's combined Shamir share key
        for party_id in range(1, num_parties + 1):
            self.ckks.construct_party_key(
                party_id,
                combined_shares[party_id]
            )
            print(f"  Party {party_id} Shamir key registered")

        print(f"\n[HE Manager] DKG complete – system ready")
        print(f"[HE Manager] The combined secret s = Σ s_i was NEVER assembled.")

    def get_batch_size(self) -> int:
        return self.batch_size

    def encrypt_to_bytes(self, data: np.ndarray) -> bytes:
        if len(data) > self.batch_size:
            raise ValueError(
                f"Data size {len(data)} exceeds batch size {self.batch_size}")
        if len(data) < self.batch_size:
            padded = np.zeros(self.batch_size)
            padded[:len(data)] = data
            data = padded
        return self.ckks.encrypt(data)

    def add_encrypted(self, ct1: bytes, ct2: bytes) -> bytes:
        return self.ckks.add_encrypted(ct1, ct2)

    def multiply_encrypted_by_scalar(self, ct: bytes, scalar: float) -> bytes:
        return self.ckks.multiply_by_scalar(ct, scalar)

    def threshold_decrypt(self, ciphertext: bytes,
                        party_indices: np.ndarray) -> np.ndarray:
        """
        Path B: Shamir partial decrypt + Lagrange combination.
        Works on any ciphertext including homomorphically aggregated ones.
        party_indices: 1-based party IDs, exactly `threshold` of them.
        """
        participating = [int(p) for p in party_indices]

        # Each participating party produces a partial decryption
        # using its Shamir share key
        partial_decryptions = []
        for party_id in participating:
            partial = self.ckks.partial_decrypt_shamir(
                party_id,
                ciphertext
            )
            partial_decryptions.append(partial)

        # Lagrange interpolation combines the partials
        return self.ckks.combine_partial_decryptions(
            partial_decryptions,
            participating
        )
# ===============================
# Dataset Loader (unchanged)
# ===============================
class InSDNDataset:
    def __init__(self):
        self.scaler = StandardScaler()

    def load_data(self):
        df = pd.read_csv("final_cicids2019_top48_features.csv")
        y  = df['Label'].values.astype(np.int32)
        X  = df.drop(columns=['Label']).values.astype(np.float64)
        print(f"Data loaded: {len(df)} rows")
        X_scaled = self.scaler.fit_transform(X)
        X_train, X_test, y_train, y_test = train_test_split(
            X_scaled, y, test_size=0.3, random_state=42, stratify=y
        )
        return X_train, X_test, y_train, y_test

    def preprocess(self, X_train, X_test):
        timesteps = 1
        features  = X_train.shape[1]
        return X_train.reshape(-1, timesteps, features), \
               X_test.reshape(-1, timesteps, features)


# ===============================
# GRU Model (unchanged)
# ===============================
def build_gru_model(input_shape, lr=0.0001):
    model = Sequential([
        GRU(256, return_sequences=True, input_shape=input_shape),
        BatchNormalization(), Dropout(0.3),
        GRU(128, return_sequences=True),
        BatchNormalization(), Dropout(0.3),
        GRU(64,  return_sequences=False),
        BatchNormalization(), Dropout(0.3),
        Dense(1, activation='sigmoid'),
    ])
    model.compile(optimizer=Adam(learning_rate=lr),
                  loss='binary_crossentropy',
                  metrics=['accuracy'])
    return model


# ===============================
# Utility functions (unchanged)
# ===============================
def load_csv_data(file_path):
    df     = pd.read_csv(file_path)
    data   = df.iloc[:, :-1].values
    labels = df.iloc[:, -1].values
    return data, labels

def create_clients(data_list, label_list, num_clients=10, initial='clients'):
    client_names = [f'{initial}_{i+1}' for i in range(num_clients)]
    data = list(zip(data_list, label_list))
    random.shuffle(data)
    size   = len(data) // num_clients
    shards = [data[i:i + size] for i in range(0, size * num_clients, size)]
    return {client_names[i]: shards[i] for i in range(len(client_names))}

def batch_data(data_shard, bs=32):
    data, label = zip(*data_shard)
    dataset = tf.data.Dataset.from_tensor_slices((list(data), list(label)))
    return dataset.shuffle(len(label)).batch(bs)

def weight_scaling_factor(clients_trn_data, client_name):
    client_names  = list(clients_trn_data.keys())
    bs            = list(clients_trn_data[client_name])[0][0].shape[0]
    global_count  = sum(
        tf.data.experimental.cardinality(clients_trn_data[n]).numpy()
        for n in client_names
    ) * bs
    local_count   = tf.data.experimental.cardinality(
        clients_trn_data[client_name]).numpy() * bs
    return local_count / global_count

def test_model(X_test, Y_test, model, comm_round):
    logits  = model.predict(X_test)
    y_pred  = (logits > 0.5).astype(int)
    y_true  = Y_test.numpy().ravel()
    acc     = accuracy_score(y_true, y_pred)
    prec    = precision_score(y_true, y_pred, average='binary')
    rec     = recall_score(y_true, y_pred, average='binary')
    f1      = f1_score(y_true, y_pred, average='binary')
    mcc     = matthews_corrcoef(y_true, y_pred)
    kappa   = cohen_kappa_score(y_true, y_pred)
    logloss = log_loss(y_true, logits)
    g_mean  = balanced_accuracy_score(y_true, y_pred)
    return acc, prec, rec, f1, mcc, kappa, logloss, g_mean, 0

def get_model_size(model):
    tmpdir = tempfile.mkdtemp()
    path   = os.path.join(tmpdir, 'tmp.h5')
    try:
        model.save(path)
        size = os.path.getsize(path) / (1024 * 1024)
    finally:
        if os.path.exists(path):   os.remove(path)
        if os.path.exists(tmpdir): os.rmdir(tmpdir)
    return size

def measure_communication_overhead(weights, num_clients):
    import pickle as pkl
    serialized          = pkl.dumps(weights)
    weights_size        = len(serialized)
    server_to_clients   = weights_size * num_clients
    clients_to_server   = weights_size * num_clients
    return {
        'server_to_clients': server_to_clients,
        'clients_to_server': clients_to_server,
        'total_round'      : server_to_clients + clients_to_server,
        'weights_size'     : weights_size,
    }

def measure_computation_time():
    class ComputationTimer:
        def __enter__(self):
            self.start_time = time.time(); return self
        def __exit__(self, *_):
            self.elapsed_time = time.time() - self.start_time
    return ComputationTimer()


# ===============================
# Federated Server (unchanged)
# ===============================
class FLServer:
    def __init__(self, num_clients, byzantine_threshold, he_manager):
        self.he                         = he_manager
        self.num_clients                = num_clients
        self.byzantine_threshold        = byzantine_threshold
        self.registered_clients         = {}
        self.registration_tokens        = {}
        self.client_hashes              = {}
        self.aggregated_hash            = None
        self.suspicious_clients         = set()
        self.malicious_updates_detected = 0
        self.encrypted_aggregated       = None

    def register_client(self, client_id, dataset_size):
        if client_id in self.registered_clients:
            return False, None
        token_data = f"{client_id}_{dataset_size}_{time.time()}"
        token      = hashlib.sha256(token_data.encode()).hexdigest()
        self.registered_clients[client_id] = {
            'token': token, 'dataset_size': dataset_size,
            'registration_time': time.time()
        }
        self.registration_tokens[token] = client_id
        print(f"[Server] Client {client_id} registered (Dataset size: {dataset_size})")
        return True, token

    def verify_client_registration(self, client_id):
        return client_id in self.registered_clients

    def receive_encrypted_update(self, client_id, encrypted_chunks, hashes):
        if not self.verify_client_registration(client_id):
            print(f"[Server] Client {client_id} not registered!")
            return False
        if not self._verify_update_integrity(encrypted_chunks, hashes):
            print(f"[Server] Hash verification failed for Client {client_id}")
            self.suspicious_clients.add(client_id)
            return False
        self.client_hashes[client_id] = hashes
        print(f"[Server] Client {client_id} update verified ({len(hashes)} chunks)")
        return True

    def _verify_update_integrity(self, encrypted_chunks, provided_hashes):
        if len(encrypted_chunks) != len(provided_hashes): return False
        for chunk, expected in zip(encrypted_chunks, provided_hashes):
            if compute_hash(chunk) != expected: return False
        return True

    def detect_byzantine_behavior(self, encrypted_updates, client_ids):
        update_sizes   = [sum(len(c) for c in u) for u in encrypted_updates]
        mean_size      = np.mean(update_sizes)
        std_size       = np.std(update_sizes)
        malicious      = []
        for size, cid in zip(update_sizes, client_ids):
            if abs(size - mean_size) > 3 * std_size:
                malicious.append(cid)
                self.suspicious_clients.add(cid)
                print(f"[Server] Byzantine behaviour detected: Client {cid}")
        attack = len(malicious) >= self.byzantine_threshold
        if attack:
            self.malicious_updates_detected += 1
            print(f"[Server] BYZANTINE ATTACK DETECTED! {len(malicious)} malicious clients")
        return attack, malicious

    def weighted_aggregate_encrypted(self, encrypted_weights_list,
                                     scaling_factors, client_ids):
        print("[Server] Performing Byzantine-resistant secure weighted aggregation...")
        attack, malicious = self.detect_byzantine_behavior(
            encrypted_weights_list, client_ids)
        if attack:
            print("[Server] ABORTING AGGREGATION – Byzantine attack detected!")
            return None, None

        if self.suspicious_clients:
            filtered = [(u, f, cid)
                        for u, f, cid in zip(encrypted_weights_list,
                                             scaling_factors, client_ids)
                        if cid not in self.suspicious_clients]
            if not filtered:
                print("[Server] No valid updates remaining after filtering!")
                return None, None
            encrypted_weights_list, scaling_factors, client_ids = zip(*filtered)
            print(f"[Server] Continuing with {len(client_ids)} trusted clients: "
                  f"{list(client_ids)}")

        num_chunks        = len(encrypted_weights_list[0])
        aggregated_chunks = []

        for chunk_idx in range(num_chunks):
            weighted = self.he.multiply_encrypted_by_scalar(
                encrypted_weights_list[0][chunk_idx], float(scaling_factors[0]))
            for ci in range(1, len(encrypted_weights_list)):
                w_i = self.he.multiply_encrypted_by_scalar(
                    encrypted_weights_list[ci][chunk_idx], float(scaling_factors[ci]))
                weighted = self.he.add_encrypted(weighted, w_i)
            aggregated_chunks.append(weighted)

        combined_data    = b''.join(aggregated_chunks)
        aggregated_hash  = compute_hash(combined_data)
        self.encrypted_aggregated = aggregated_chunks
        self.aggregated_hash      = aggregated_hash

        print(f"[Server] Aggregation complete "
              f"(scaling factors: {[f'{s:.4f}' for s in scaling_factors]})")
        print(f"[Server] Aggregated hash: {aggregated_hash[:32]}...")
        return aggregated_chunks, aggregated_hash


# ===============================
# Encrypt / Decrypt helpers (unchanged)
# ===============================
def encrypt_weights(he_manager, weights) -> Tuple[List[bytes], List[str]]:
    flat       = np.concatenate([w.flatten() for w in weights])
    slot_limit = he_manager.get_batch_size()
    encrypted_chunks, hashes = [], []
    for i in range(0, len(flat), slot_limit):
        chunk     = flat[i:i + slot_limit]
        enc_chunk = he_manager.encrypt_to_bytes(chunk)
        encrypted_chunks.append(enc_chunk)
        hashes.append(compute_hash(enc_chunk))
    return encrypted_chunks, hashes


def decrypt_aggregated(he_manager, encrypted_aggregated,
                        party_indices, reference_weights):
    decrypted_chunks = [
        he_manager.threshold_decrypt(enc, party_indices)
        for enc in encrypted_aggregated
    ]
    flat_weights = np.concatenate(decrypted_chunks)
    new_weights, idx = [], 0
    for w in reference_weights:
        size = np.prod(w.shape)
        new_weights.append(flat_weights[idx:idx + size].reshape(w.shape))
        idx += size
    return new_weights


def verify_aggregated_integrity(encrypted_aggregated, aggregated_hash):
    return compute_hash(b''.join(encrypted_aggregated)) == aggregated_hash


# ===============================
# Main
# ===============================

print("=" * 70)
print("FEDERATED LEARNING WITH DKG-BASED TRUE THRESHOLD HOMOMORPHIC ENCRYPTION")
print("=" * 70)

results_dir = '4_CICDDoS17_dkg_true'
os.makedirs(results_dir, exist_ok=True)

# ── Data loading ───────────────────────────────────────────────────────
data_path = "../final_cicids2017_top48_features.csv"
data_list, label_list = load_csv_data(data_path)
print(len(np.unique(label_list)))

scaler    = StandardScaler()
data_list = scaler.fit_transform(data_list)

X_train, X_test, y_train, y_test = train_test_split(
    data_list, label_list, test_size=0.3, random_state=42, stratify=label_list)

X_train = np.expand_dims(X_train, axis=1)
X_test  = np.expand_dims(X_test,  axis=1)

# ── FL settings ────────────────────────────────────────────────────────
comms_round       = 15
lr                = 0.00005
num_clients       = 4
threshold         = 3
byzantine_threshold = 2

clients        = create_clients(X_train, y_train,
                                num_clients=num_clients, initial='client')
clients_batched = {name: batch_data(data)
                   for name, data in clients.items()}
test_batched    = tf.data.Dataset.from_tensor_slices(
    (X_test, y_test)).batch(len(y_test))

# ── Initialise DKG-based HE ────────────────────────────────────────────
print("\n" + "=" * 70)
print("INITIALISING DKG-BASED TRUE THRESHOLD HOMOMORPHIC ENCRYPTION")
print("=" * 70)

# TrueThresholdCKKSWrapper now runs the full 3-phase DKG internally.
he_manager = TrueThresholdCKKSWrapper(
    num_parties = num_clients,
    threshold   = threshold,
    ring_dim    = 8192,
    batch_size  = 4096,
    mult_depth  = 2,
    scale_bits  = 40
)

# ── Server & client registration ───────────────────────────────────────
server       = FLServer(num_clients, byzantine_threshold, he_manager)
client_names = list(clients_batched.keys())

print(f"\n{'=' * 70}")
print("CLIENT REGISTRATION PHASE")
print(f"{'=' * 70}")
for i, client_name in enumerate(client_names):
    dataset_size = len(list(clients_batched[client_name])) * 32
    success, _   = server.register_client(i, dataset_size)
    if not success:
        print(f"[FATAL] Client {client_name} registration failed!");
print(f"\nAll {num_clients} clients registered successfully")

# ── Model & CSV setup ──────────────────────────────────────────────────
input_shape  = (X_train.shape[1], X_train.shape[2])
global_model = build_gru_model(input_shape, lr=lr)

out_client  = os.path.join(results_dir, "dkg_client_metrics_4.csv")
out_global  = os.path.join(results_dir, "dkg_each_round_metrics_4.csv")
out_comm    = os.path.join(results_dir, "dkg_communication_computation_metrics_4.csv")

with open(out_client, 'w', newline='') as f:
    csv.writer(f).writerow(["Communication Round", "Client", "Loss", "Accuracy",
                             "Precision", "Recall", "auc",
                             "Encryption_Time_sec", "Decryption_Time_sec"])
with open(out_global, 'w', newline='') as f:
    csv.writer(f).writerow(["comm_round", "global_acc", "global_precision",
                             "global_recall", "global_f1", "global_mcc",
                             "global_cohen_kappa", "global_logloss",
                             "global_g_mean", "global_loss"])
with open(out_comm, 'w', newline='') as f:
    csv.writer(f).writerow([
        "comm_round", "server_to_clients_mb", "clients_to_server_mb",
        "total_round_mb", "weights_size_mb", "encrypted_weights_size_mb",
        "encryption_overhead_mb", "round_computation_time_sec",
        "avg_client_training_time_sec", "weight_aggregation_time_sec",
        "avg_encryption_time_sec", "avg_decryption_time_sec",
        "encryption_time_sec", "decryption_time_sec", "aggregation_time_sec"])

# ── Tracking variables ─────────────────────────────────────────────────
total_communication_overhead = 0
total_computation_time       = 0
total_encryption_time        = 0
total_decryption_time        = 0
total_aggregation_time       = 0
total_encryption_overhead    = 0

encrypted_global_weights = None
encrypted_weights_size_mb = 0.0

# ── Training loop ──────────────────────────────────────────────────────
for comm_round in range(comms_round):
    print(f"\n{'=' * 70}")
    print(f"COMMUNICATION ROUND {comm_round + 1}/{comms_round}")
    print(f"{'=' * 70}")

    with measure_computation_time() as round_timer:

        global_weights    = global_model.get_weights()
        decryption_times  = []
        round_decryption_time = 0

        # Decrypt previous round's aggregated model (if any)
        if comm_round > 0 and encrypted_global_weights is not None:
            print("[CLIENTS] Decrypting aggregated model...")
            t0 = time.time()

            dec_indices  = sorted(random.sample(range(num_clients), threshold))
            party_indices = np.array([idx + 1 for idx in dec_indices], dtype=np.int32)
            print(f"[Decryption] Selected parties: {dec_indices}")

            current_weights = decrypt_aggregated(
                he_manager, encrypted_global_weights,
                party_indices, global_model.get_weights())

            decrypt_time = time.time() - t0
            decryption_times.append(decrypt_time)
            round_decryption_time = decrypt_time
            total_decryption_time += decrypt_time
            print(f"Decryption: {decrypt_time:.2f}s")
        else:
            current_weights = global_weights
            decrypt_time    = 0

        comm_overhead = measure_communication_overhead(current_weights, num_clients)
        comm_mb       = {k: v / (1024 * 1024) for k, v in comm_overhead.items()}

        random.shuffle(client_names)

        client_training_times = []
        encryption_times      = []
        round_encryption_time = 0
        encrypted_updates     = []
        update_hashes_list    = []
        participating_clients = []
        scaling_factors       = []

        for client in client_names:
            client_idx = client_names.index(client)
            print(f"\n[{client}] Local training...")

            with measure_computation_time() as ct:
                local_model = build_gru_model(input_shape, lr=lr)
                local_model.set_weights(current_weights)
                history = local_model.fit(clients_batched[client],
                                          epochs=5, verbose=1)

            client_training_times.append(ct.elapsed_time)
            trained_weights = local_model.get_weights()

            print(f"[{client}] Encrypting weights...")
            t0 = time.time()
            enc_chunks, hashes = encrypt_weights(he_manager, trained_weights)
            encrypt_time = time.time() - t0
            encryption_times.append(encrypt_time)
            round_encryption_time += encrypt_time
            total_encryption_time += encrypt_time
            print(f"Encryption: {encrypt_time:.2f}s")

            sf = weight_scaling_factor(clients_batched, client)
            if server.receive_encrypted_update(client_idx, enc_chunks, hashes):
                encrypted_updates.append(enc_chunks)
                update_hashes_list.append(hashes)
                participating_clients.append(client_idx)
                scaling_factors.append(sf)
                print(f"Server accepted model from {client}")
            else:
                print(f"Server rejected model from {client}")

            with open(out_client, 'a', newline='') as f:
                csv.writer(f).writerow([
                    comm_round, client,
                    history.history['loss'][-1],
                    history.history['accuracy'][-1],
                    0, 0, 0, encrypt_time, decrypt_time])

            tf.keras.backend.clear_session()

        if len(participating_clients) < threshold:
            print(f"\nWARNING: Only {len(participating_clients)} clients, "
                  f"need {threshold}. Skipping round.")
            continue

        # Server-side secure aggregation
        print(f"\n[SERVER] Secure aggregation (homomorphic weighted sum)...")
        with measure_computation_time() as agg_timer:
            aggregated_chunks, aggregated_hash = \
                server.weighted_aggregate_encrypted(
                    encrypted_updates, scaling_factors, participating_clients)

        total_aggregation_time += agg_timer.elapsed_time
        print(f"Aggregation: {agg_timer.elapsed_time:.2f}s")

        if aggregated_chunks is None:
            print(f"ROUND {comm_round + 1} ABORTED – Byzantine attack detected!")
            server.suspicious_clients.clear()
            continue

        print(f"\n[Hash Verification] Verifying aggregated result...")
        if not verify_aggregated_integrity(aggregated_chunks, aggregated_hash):
            print(f"ROUND {comm_round + 1} ABORTED – Hash verification failed!")
            continue
        print("Aggregated hash verified ✓")

        encrypted_global_weights  = aggregated_chunks
        encrypted_weights_size    = sum(len(c) for c in encrypted_global_weights)
        encrypted_weights_size_mb = encrypted_weights_size / (1024 * 1024)
        encryption_overhead_mb    = (encrypted_weights_size -
                                     comm_overhead['weights_size']) / (1024 * 1024)
        total_encryption_overhead += (encrypted_weights_size -
                                      comm_overhead['weights_size'])

        # Final decryption for evaluation
        print(f"\n[CLIENTS] Decrypting aggregated model for evaluation...")
        t0 = time.time()
        fin_indices   = sorted(random.sample(range(num_clients), threshold))
        party_final   = np.array([idx + 1 for idx in fin_indices], dtype=np.int32)
        final_weights = decrypt_aggregated(
            he_manager, encrypted_global_weights,
            party_final, global_model.get_weights())
        final_dec_time = time.time() - t0
        total_decryption_time += final_dec_time
        print(f"Final decryption: {final_dec_time:.2f}s")

        global_model.set_weights(final_weights)

    total_computation_time        += round_timer.elapsed_time
    total_communication_overhead  += encrypted_weights_size * num_clients * 2

    avg_client_training = np.mean(client_training_times)
    avg_enc_time        = np.mean(encryption_times)
    avg_dec_time        = np.mean(decryption_times) if decryption_times else 0

    with open(out_comm, 'a', newline='') as f:
        csv.writer(f).writerow([
            comm_round,
            comm_mb['server_to_clients'], comm_mb['clients_to_server'],
            comm_mb['total_round'],       comm_mb['weights_size'],
            encrypted_weights_size_mb,    encryption_overhead_mb,
            round_timer.elapsed_time,     avg_client_training,
            agg_timer.elapsed_time,       avg_enc_time,
            avg_dec_time,                 round_encryption_time,
            round_decryption_time,        agg_timer.elapsed_time])

    for X_batch, Y_batch in test_batched:
        (global_acc, global_precision, global_recall, global_f1,
         global_mcc, global_kappa, global_logloss,
         global_g_mean, global_loss) = test_model(X_batch, Y_batch,
                                                   global_model, comm_round)
        print(f'comm_round: {comm_round} | '
              f'global_acc: {global_acc:.3%} | '
              f'global_precision: {global_precision:.3%} | '
              f'global_recall: {global_recall:.3%} | '
              f'global_f1: {global_f1:.3%} | '
              f'global_mcc: {global_mcc:.3%} | '
              f'global_cohen_kappa: {global_kappa:.3} | '
              f'global_logloss: {global_logloss:.3%} | '
              f'global_g_mean: {global_g_mean:.3}')

    with open(out_global, 'a', newline='') as f:
        csv.writer(f).writerow([
            comm_round, global_acc, global_precision, global_recall,
            global_f1, global_mcc, global_kappa, global_logloss,
            global_g_mean, global_loss])

# ── Final summary ──────────────────────────────────────────────────────
print(f"\n{'=' * 70}")
print(f"FINAL DKG TRUE THRESHOLD FEDERATED LEARNING SUMMARY")
print(f"{'=' * 70}")
print(f"Total Communication Overhead : "
      f"{total_communication_overhead / (1024 * 1024):.2f} MB")
print(f"Total Computation Time       : {total_computation_time:.2f}s")
print(f"Total Encryption Time        : {total_encryption_time:.2f}s")
print(f"Total Decryption Time        : {total_decryption_time:.2f}s")
print(f"Total Aggregation Time       : {total_aggregation_time:.2f}s")
print(f"Avg Communication per Round  : "
      f"{(total_communication_overhead / comms_round) / (1024 * 1024):.2f} MB")
print(f"Avg Computation per Round    : "
      f"{total_computation_time / comms_round:.2f}s")

summary = {
    'total_communication_mb'         : total_communication_overhead / (1024 * 1024),
    'total_computation_time_sec'     : total_computation_time,
    'total_encryption_time_sec'      : total_encryption_time,
    'total_decryption_time_sec'      : total_decryption_time,
    'total_aggregation_time_sec'     : total_aggregation_time,
    'avg_communication_per_round_mb' : (total_communication_overhead / comms_round) / (1024 * 1024),
    'avg_computation_per_round_sec'  : total_computation_time / comms_round,
    'num_rounds'  : comms_round,
    'num_clients' : num_clients,
    'threshold'   : threshold,
    'dkg_enabled' : True,
}
summary_path = os.path.join(results_dir, "dkg_summary_metrics_4.csv")
with open(summary_path, 'w', newline='') as f:
    w = csv.writer(f)
    w.writerow(["Metric", "Value"])
    for k, v in summary.items():
        w.writerow([k, v])

for X_batch, Y_batch in test_batched:
    (acc, prec, rec, f1, mcc, kappa,
     logloss, g_mean, _) = test_model(X_batch, Y_batch, global_model, 0)
    print(f'Final Results | '
          f'acc: {acc:.3%} | prec: {prec:.3%} | recall: {rec:.3%} | '
          f'f1: {f1:.3%} | mcc: {mcc:.3%} | kappa: {kappa:.3} | '
          f'logloss: {logloss:.3%} | g_mean: {g_mean:.3}')

global_model.save(os.path.join(results_dir, 'dkg_Federated_model_4.h5'))

# ── Centralised baseline ───────────────────────────────────────────────
print(f"\n{'=' * 70}")
print(f"CENTRALISED TRAINING FOR COMPARISON")
print(f"{'=' * 70}")
with measure_computation_time() as ct:
    sgd_ds    = tf.data.Dataset.from_tensor_slices(
        (X_train, y_train)).shuffle(len(y_train)).batch(512)
    sgd_model = build_gru_model(input_shape, lr=0.001)
    sgd_model.fit(sgd_ds, epochs=1, verbose=True)
print(f"Centralised training time: {ct.elapsed_time:.2f}s")

for X_batch, Y_batch in test_batched:
    (acc, prec, rec, f1, mcc, kappa,
     logloss, g_mean, _) = test_model(X_batch, Y_batch, sgd_model, 1)
    print(f'Centralised | '
          f'acc: {acc:.3%} | prec: {prec:.3%} | recall: {rec:.3%} | '
          f'f1: {f1:.3%} | mcc: {mcc:.3%} | kappa: {kappa:.3} | '
          f'logloss: {logloss:.3%} | g_mean: {g_mean:.3}')

print("\n" + "=" * 70)
print("ALL TRAINING COMPLETE!")
print("=" * 70)

blacklisted = server.suspicious_clients
print(f"\nBlacklisted malicious clients: {blacklisted}"
      if blacklisted else "\nNo malicious clients detected during training")
# Out:
# 2026-05-20 02:52:09.980851: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-20 02:52:10.006285: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ======================================================================
# FEDERATED LEARNING WITH DKG-BASED TRUE THRESHOLD HOMOMORPHIC ENCRYPTION
# ======================================================================
# 2
# 2026-05-20 02:52:15.157309: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-05-20 02:52:15.160103: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-05-20 02:52:15.160189: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-05-20 02:52:15.160809: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-05-20 02:52:15.160892: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-05-20 02:52:15.160962: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-05-20 02:52:15.201405: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-05-20 02:52:15.201521: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-05-20 02:52:15.201596: I tensorflow/compiler/xla/stream_executor/cuda/cuda_gpu_executor.cc:995] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2026-05-20 02:52:15.201659: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1639] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 22446 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3090, pci bus id: 0000:01:00.0, compute capability: 8.6
# ======================================================================
# INITIALISING DKG-BASED TRUE THRESHOLD HOMOMORPHIC ENCRYPTION
# ======================================================================
# [HE Manager] Initialising DKG-based TRUE threshold CKKS
#   Threshold : 3-of-4
#   Ring dim  : 8192,  Batch size: 4096
#
# [HE Manager] DKG Phase 1 – chain key generation
# [TrueThresholdCKKS] Context ready. ring_dim=8192 batch_size=4096 mult_depth=2 scale_bits=40 threshold=3-of-4 mode=NOISE_FLOODING_MULTIPARTY
#   Party 1 (lead) done
#   Party 2 (join) done
#   Party 3 (join) done
#   Party 4 (join) done
#
# [HE Manager] DKG Phase 2 – finalizing joint public key
# [HE Manager] Joint pk ready — combined secret was NEVER assembled
#
# [HE Manager] DKG Phase 3 – collaborative EvalMult key
# [DKG] Party 1 (lead) keypair generated. s_1 stored (8192 coeffs).
# [DKG] Party 2 (join) keypair generated. s_2 stored (8192 coeffs).
# [DKG] Party 3 (join) keypair generated. s_3 stored (8192 coeffs).
# [DKG] Party 4 (join) keypair generated. s_4 stored (8192 coeffs).
# [DKG] Joint public key finalized. Joint secret s=Σs_i was NEVER assembled in one place.
# [DKG] Party 1 EvalMult share generated.
# [DKG] Party 2 EvalMult key joined.
# [DKG] Party 3 EvalMult key joined.
# [DKG] Party 4 EvalMult key joined.
# [HE Manager] EvalMult key ready
#
# [HE Manager] DKG Phase 4 – Shamir backup shares
# [DKG] Joint EvalMult key installed.
# [Shamir] Party 1 generating 3-of-4 shares of s_1
# [Shamir] Party 1 shares ready.
# [Shamir] Party 2 generating 3-of-4 shares of s_2
# [Shamir] Party 2 shares ready.
# [Shamir] Party 3 generating 3-of-4 shares of s_3
#   Party 1 Shamir key registered
#   Party 2 Shamir key registered
#   Party 3 Shamir key registered
#   Party 4 Shamir key registered
#
# [HE Manager] DKG complete – system ready
# [HE Manager] The combined secret s = Σ s_i was NEVER assembled.
#
# ======================================================================
# CLIENT REGISTRATION PHASE
# ======================================================================
# [Shamir] Party 3 shares ready.
# [Shamir] Party 4 generating 3-of-4 shares of s_4
# [Shamir] Party 4 shares ready.
# [Shamir] Constructing Shamir key for party 1 (8192 coeffs)
# [Shamir] Party 1 Shamir key stored.
# [Shamir] Constructing Shamir key for party 2 (8192 coeffs)
# [Shamir] Party 2 Shamir key stored.
# [Shamir] Constructing Shamir key for party 3 (8192 coeffs)
# [Shamir] Party 3 Shamir key stored.
# [Shamir] Constructing Shamir key for party 4 (8192 coeffs)
# [Shamir] Party 4 Shamir key stored.
# [Server] Client 0 registered (Dataset size: 148992)
# [Server] Client 1 registered (Dataset size: 148992)
# [Server] Client 2 registered (Dataset size: 148992)
# [Server] Client 3 registered (Dataset size: 148992)
#
# All 4 clients registered successfully
#
# ======================================================================
# COMMUNICATION ROUND 1/15
# ======================================================================
#
# [client_2] Local training...
# Epoch 1/5
# 2026-05-20 02:52:26.392854: I tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:432] Loaded cuDNN version 8600
# 2026-05-20 02:52:26.436249: I tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:606] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 2026-05-20 02:52:26.438953: I tensorflow/compiler/xla/service/service.cc:168] XLA service 0x76261f0e91c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2026-05-20 02:52:26.438970: I tensorflow/compiler/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 3090, Compute Capability 8.6
# 2026-05-20 02:52:26.441830: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:255] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2026-05-20 02:52:26.507726: I ./tensorflow/compiler/jit/device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 4656/4656 [==============================] - 16s 3ms/step - loss: 0.2488 - accuracy: 0.8925
# Epoch 2/5
# 4656/4656 [==============================] - 13s 3ms/step - loss: 0.1685 - accuracy: 0.9332
# Epoch 3/5
# 4656/4656 [==============================] - 13s 3ms/step - loss: 0.1437 - accuracy: 0.9431
# Epoch 4/5
# 4656/4656 [==============================] - 13s 3ms/step - loss: 0.1305 - accuracy: 0.9485
# Epoch 5/5
# 4656/4656 [==============================] - 13s 3ms/step - loss: 0.1210 - accuracy: 0.9523
# [client_2] Encrypting weights...
# Encryption: 0.32s
# [Server] Client 0 update verified (104 chunks)
# Server accepted model from client_2
#
# [client_4] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 16s 3ms/step - loss: 0.2481 - accuracy: 0.8933
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.1669 - accuracy: 0.9331
# Epoch 3/5
# 4656/4656 [==============================] - 13s 3ms/step - loss: 0.1435 - accuracy: 0.9429
# Epoch 4/5
# 4656/4656 [==============================] - 13s 3ms/step - loss: 0.1297 - accuracy: 0.9493
# Epoch 5/5
# 4656/4656 [==============================] - 13s 3ms/step - loss: 0.1203 - accuracy: 0.9524
# [client_4] Encrypting weights...
# Encryption: 0.32s
# [Server] Client 1 update verified (104 chunks)
# Server accepted model from client_4
#
# [client_1] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 16s 3ms/step - loss: 0.2486 - accuracy: 0.8932
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.1685 - accuracy: 0.9333
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.1458 - accuracy: 0.9426
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.1310 - accuracy: 0.9489
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.1218 - accuracy: 0.9527
# [client_1] Encrypting weights...
# Encryption: 0.32s
# [Server] Client 2 update verified (104 chunks)
# Server accepted model from client_1
#
# [client_3] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 16s 3ms/step - loss: 0.2476 - accuracy: 0.8936
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.1696 - accuracy: 0.9327
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.1455 - accuracy: 0.9428
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.1317 - accuracy: 0.9493
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.1230 - accuracy: 0.9519
# [client_3] Encrypting weights...
# Encryption: 0.32s
# [Server] Client 3 update verified (104 chunks)
# Server accepted model from client_3
#
# [SERVER] Secure aggregation (homomorphic weighted sum)...
# [Server] Performing Byzantine-resistant secure weighted aggregation...
# [Server] Aggregation complete (scaling factors: ['0.2500', '0.2500', '0.2500', '0.2500'])
# [Server] Aggregated hash: 397203ff0597bc8506c5fd863ab72909...
# Aggregation: 1.94s
#
# [Hash Verification] Verifying aggregated result...
# Aggregated hash verified ✓
#
# [CLIENTS] Decrypting aggregated model for evaluation...
# Final decryption: 1.45s
# 7982/7982 [==============================] - 8s 908us/step
# comm_round: 0 | global_acc: 96.240% | global_precision: 96.556% | global_recall: 95.901% | global_f1: 96.227% | global_mcc: 92.482% | global_cohen_kappa: 0.925 | global_logloss: 9.140% | global_g_mean: 0.962
#
# ======================================================================
# COMMUNICATION ROUND 2/15
# ======================================================================
# [CLIENTS] Decrypting aggregated model...
# [Decryption] Selected parties: [0, 1, 3]
# Decryption: 1.46s
#
# [client_3] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 16s 3ms/step - loss: 0.1155 - accuracy: 0.9545
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.1108 - accuracy: 0.9569
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.1073 - accuracy: 0.9577
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.1024 - accuracy: 0.9593
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0997 - accuracy: 0.9609
# [client_3] Encrypting weights...
# Encryption: 0.31s
# [Server] Client 0 update verified (104 chunks)
# Server accepted model from client_3
#
# [client_4] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 16s 3ms/step - loss: 0.1143 - accuracy: 0.9553
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.1097 - accuracy: 0.9567
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.1045 - accuracy: 0.9589
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.1007 - accuracy: 0.9602
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0977 - accuracy: 0.9608
# [client_4] Encrypting weights...
# Encryption: 0.32s
# [Server] Client 1 update verified (104 chunks)
# Server accepted model from client_4
#
# [client_2] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 16s 3ms/step - loss: 0.1155 - accuracy: 0.9547
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.1093 - accuracy: 0.9566
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.1050 - accuracy: 0.9588
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.1013 - accuracy: 0.9592
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0992 - accuracy: 0.9600
# [client_2] Encrypting weights...
# Encryption: 0.31s
# [Server] Client 2 update verified (104 chunks)
# Server accepted model from client_2
#
# [client_1] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 16s 3ms/step - loss: 0.1156 - accuracy: 0.9550
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.1103 - accuracy: 0.9569
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.1055 - accuracy: 0.9583
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.1025 - accuracy: 0.9597
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0990 - accuracy: 0.9609
# [client_1] Encrypting weights...
# Encryption: 0.32s
# [Server] Client 3 update verified (104 chunks)
# Server accepted model from client_1
#
# [SERVER] Secure aggregation (homomorphic weighted sum)...
# [Server] Performing Byzantine-resistant secure weighted aggregation...
# [Server] Aggregation complete (scaling factors: ['0.2500', '0.2500', '0.2500', '0.2500'])
# [Server] Aggregated hash: 8d8e7ef656f0b7afefee0d4b65b7644e...
# Aggregation: 1.93s
#
# [Hash Verification] Verifying aggregated result...
# Aggregated hash verified ✓
#
# [CLIENTS] Decrypting aggregated model for evaluation...
# Final decryption: 1.48s
# 7982/7982 [==============================] - 7s 904us/step
# comm_round: 1 | global_acc: 96.551% | global_precision: 97.151% | global_recall: 95.915% | global_f1: 96.529% | global_mcc: 93.110% | global_cohen_kappa: 0.931 | global_logloss: 7.675% | global_g_mean: 0.966
#
# ======================================================================
# COMMUNICATION ROUND 3/15
# ======================================================================
# [CLIENTS] Decrypting aggregated model...
# [Decryption] Selected parties: [0, 1, 2]
# Decryption: 1.48s
#
# [client_4] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 17s 3ms/step - loss: 0.0944 - accuracy: 0.9627
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0932 - accuracy: 0.9634
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0896 - accuracy: 0.9645
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0883 - accuracy: 0.9657
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0863 - accuracy: 0.9666
# [client_4] Encrypting weights...
# Encryption: 0.32s
# [Server] Client 0 update verified (104 chunks)
# Server accepted model from client_4
#
# [client_2] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 17s 3ms/step - loss: 0.0942 - accuracy: 0.9625
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0930 - accuracy: 0.9630
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0921 - accuracy: 0.9633
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0889 - accuracy: 0.9651
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0872 - accuracy: 0.9658
# [client_2] Encrypting weights...
# Encryption: 0.32s
# [Server] Client 1 update verified (104 chunks)
# Server accepted model from client_2
#
# [client_3] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 16s 3ms/step - loss: 0.0973 - accuracy: 0.9617
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0932 - accuracy: 0.9636
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0910 - accuracy: 0.9640
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0904 - accuracy: 0.9644
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0873 - accuracy: 0.9665
# [client_3] Encrypting weights...
# Encryption: 0.32s
# [Server] Client 2 update verified (104 chunks)
# Server accepted model from client_3
#
# [client_1] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 16s 3ms/step - loss: 0.0964 - accuracy: 0.9620
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0943 - accuracy: 0.9627
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0918 - accuracy: 0.9638
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0891 - accuracy: 0.9650
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0876 - accuracy: 0.9659
# [client_1] Encrypting weights...
# Encryption: 0.31s
# [Server] Client 3 update verified (104 chunks)
# Server accepted model from client_1
#
# [SERVER] Secure aggregation (homomorphic weighted sum)...
# [Server] Performing Byzantine-resistant secure weighted aggregation...
# [Server] Aggregation complete (scaling factors: ['0.2500', '0.2500', '0.2500', '0.2500'])
# [Server] Aggregated hash: 0121b52cc90df089c728d327d01f387f...
# Aggregation: 1.95s
#
# [Hash Verification] Verifying aggregated result...
# Aggregated hash verified ✓
#
# [CLIENTS] Decrypting aggregated model for evaluation...
# Final decryption: 1.49s
# 7982/7982 [==============================] - 7s 909us/step
# comm_round: 2 | global_acc: 97.687% | global_precision: 97.160% | global_recall: 98.247% | global_f1: 97.700% | global_mcc: 95.381% | global_cohen_kappa: 0.954 | global_logloss: 6.912% | global_g_mean: 0.977
#
# ======================================================================
# COMMUNICATION ROUND 4/15
# ======================================================================
# [CLIENTS] Decrypting aggregated model...
# [Decryption] Selected parties: [0, 2, 3]
# Decryption: 1.49s
#
# [client_2] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 17s 3ms/step - loss: 0.0850 - accuracy: 0.9668
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0830 - accuracy: 0.9676
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0817 - accuracy: 0.9683
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0797 - accuracy: 0.9695
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0786 - accuracy: 0.9697
# [client_2] Encrypting weights...
# Encryption: 0.32s
# [Server] Client 0 update verified (104 chunks)
# Server accepted model from client_2
#
# [client_3] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 17s 3ms/step - loss: 0.0852 - accuracy: 0.9669
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0836 - accuracy: 0.9682
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0823 - accuracy: 0.9686
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0810 - accuracy: 0.9695
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0792 - accuracy: 0.9698
# [client_3] Encrypting weights...
# Encryption: 0.32s
# [Server] Client 1 update verified (104 chunks)
# Server accepted model from client_3
#
# [client_1] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 16s 3ms/step - loss: 0.0855 - accuracy: 0.9670
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0843 - accuracy: 0.9679
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0826 - accuracy: 0.9690
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0817 - accuracy: 0.9690
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0796 - accuracy: 0.9697
# [client_1] Encrypting weights...
# Encryption: 0.31s
# [Server] Client 2 update verified (104 chunks)
# Server accepted model from client_1
#
# [client_4] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 16s 3ms/step - loss: 0.0837 - accuracy: 0.9676
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0827 - accuracy: 0.9682
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0805 - accuracy: 0.9691
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0790 - accuracy: 0.9702
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0782 - accuracy: 0.9706
# [client_4] Encrypting weights...
# Encryption: 0.32s
# [Server] Client 3 update verified (104 chunks)
# Server accepted model from client_4
#
# [SERVER] Secure aggregation (homomorphic weighted sum)...
# [Server] Performing Byzantine-resistant secure weighted aggregation...
# [Server] Aggregation complete (scaling factors: ['0.2500', '0.2500', '0.2500', '0.2500'])
# [Server] Aggregated hash: ed3af7661abfe08af1538cc5ad0da722...
# Aggregation: 1.95s
#
# [Hash Verification] Verifying aggregated result...
# Aggregated hash verified ✓
#
# [CLIENTS] Decrypting aggregated model for evaluation...
# Final decryption: 1.50s
# 7982/7982 [==============================] - 7s 911us/step
# comm_round: 3 | global_acc: 97.469% | global_precision: 96.327% | global_recall: 98.703% | global_f1: 97.500% | global_mcc: 94.967% | global_cohen_kappa: 0.949 | global_logloss: 6.348% | global_g_mean: 0.975
#
# ======================================================================
# COMMUNICATION ROUND 5/15
# ======================================================================
# [CLIENTS] Decrypting aggregated model...
# [Decryption] Selected parties: [0, 1, 2]
# Decryption: 1.48s
#
# [client_3] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 17s 3ms/step - loss: 0.0777 - accuracy: 0.9708
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0766 - accuracy: 0.9712
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0760 - accuracy: 0.9717
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0748 - accuracy: 0.9718
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0735 - accuracy: 0.9729
# [client_3] Encrypting weights...
# Encryption: 0.32s
# [Server] Client 0 update verified (104 chunks)
# Server accepted model from client_3
#
# [client_4] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 17s 3ms/step - loss: 0.0756 - accuracy: 0.9717
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0749 - accuracy: 0.9722
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0740 - accuracy: 0.9724
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0721 - accuracy: 0.9734
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0709 - accuracy: 0.9740
# [client_4] Encrypting weights...
# Encryption: 0.32s
# [Server] Client 1 update verified (104 chunks)
# Server accepted model from client_4
#
# [client_2] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 16s 3ms/step - loss: 0.0768 - accuracy: 0.9710
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0755 - accuracy: 0.9717
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0749 - accuracy: 0.9720
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0735 - accuracy: 0.9727
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0726 - accuracy: 0.9734
# [client_2] Encrypting weights...
# Encryption: 0.31s
# [Server] Client 2 update verified (104 chunks)
# Server accepted model from client_2
#
# [client_1] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 16s 3ms/step - loss: 0.0778 - accuracy: 0.9710
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0762 - accuracy: 0.9716
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0746 - accuracy: 0.9723
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0738 - accuracy: 0.9726
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0724 - accuracy: 0.9730
# [client_1] Encrypting weights...
# Encryption: 0.31s
# [Server] Client 3 update verified (104 chunks)
# Server accepted model from client_1
#
# [SERVER] Secure aggregation (homomorphic weighted sum)...
# [Server] Performing Byzantine-resistant secure weighted aggregation...
# [Server] Aggregation complete (scaling factors: ['0.2500', '0.2500', '0.2500', '0.2500'])
# [Server] Aggregated hash: 19d4482b65120d77569d8196e074ddbc...
# Aggregation: 1.95s
#
# [Hash Verification] Verifying aggregated result...
# Aggregated hash verified ✓
#
# [CLIENTS] Decrypting aggregated model for evaluation...
# Final decryption: 1.50s
# 7982/7982 [==============================] - 7s 908us/step
# comm_round: 4 | global_acc: 97.874% | global_precision: 97.268% | global_recall: 98.516% | global_f1: 97.888% | global_mcc: 95.757% | global_cohen_kappa: 0.957 | global_logloss: 5.721% | global_g_mean: 0.979
#
# ======================================================================
# COMMUNICATION ROUND 6/15
# ======================================================================
# [CLIENTS] Decrypting aggregated model...
# [Decryption] Selected parties: [1, 2, 3]
# Decryption: 1.49s
#
# [client_4] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 17s 3ms/step - loss: 0.0702 - accuracy: 0.9745
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0697 - accuracy: 0.9744
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0684 - accuracy: 0.9749
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0674 - accuracy: 0.9752
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0668 - accuracy: 0.9756
# [client_4] Encrypting weights...
# Encryption: 0.31s
# [Server] Client 0 update verified (104 chunks)
# Server accepted model from client_4
#
# [client_1] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 17s 3ms/step - loss: 0.0714 - accuracy: 0.9739
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0704 - accuracy: 0.9741
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0697 - accuracy: 0.9742
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0689 - accuracy: 0.9744
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0680 - accuracy: 0.9748
# [client_1] Encrypting weights...
# Encryption: 0.32s
# [Server] Client 1 update verified (104 chunks)
# Server accepted model from client_1
#
# [client_2] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 16s 3ms/step - loss: 0.0709 - accuracy: 0.9733
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0710 - accuracy: 0.9734
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0688 - accuracy: 0.9743
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0682 - accuracy: 0.9745
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0676 - accuracy: 0.9744
# [client_2] Encrypting weights...
# Encryption: 0.32s
# [Server] Client 2 update verified (104 chunks)
# Server accepted model from client_2
#
# [client_3] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 16s 3ms/step - loss: 0.0712 - accuracy: 0.9741
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0702 - accuracy: 0.9739
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0704 - accuracy: 0.9739
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0693 - accuracy: 0.9742
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0681 - accuracy: 0.9747
# [client_3] Encrypting weights...
# Encryption: 0.32s
# [Server] Client 3 update verified (104 chunks)
# Server accepted model from client_3
#
# [SERVER] Secure aggregation (homomorphic weighted sum)...
# [Server] Performing Byzantine-resistant secure weighted aggregation...
# [Server] Aggregation complete (scaling factors: ['0.2500', '0.2500', '0.2500', '0.2500'])
# [Server] Aggregated hash: 6ee41ec45b30d67ccda7ead8c15f1c29...
# Aggregation: 1.95s
#
# [Hash Verification] Verifying aggregated result...
# Aggregated hash verified ✓
#
# [CLIENTS] Decrypting aggregated model for evaluation...
# Final decryption: 1.51s
# 7982/7982 [==============================] - 7s 914us/step
# comm_round: 5 | global_acc: 97.932% | global_precision: 97.354% | global_recall: 98.542% | global_f1: 97.945% | global_mcc: 95.871% | global_cohen_kappa: 0.959 | global_logloss: 5.322% | global_g_mean: 0.979
#
# ======================================================================
# COMMUNICATION ROUND 7/15
# ======================================================================
# [CLIENTS] Decrypting aggregated model...
# [Decryption] Selected parties: [1, 2, 3]
# Decryption: 1.48s
#
# [client_4] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 17s 3ms/step - loss: 0.0653 - accuracy: 0.9758
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0647 - accuracy: 0.9757
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0642 - accuracy: 0.9760
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0625 - accuracy: 0.9768
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0616 - accuracy: 0.9769
# [client_4] Encrypting weights...
# Encryption: 0.32s
# [Server] Client 0 update verified (104 chunks)
# Server accepted model from client_4
#
# [client_3] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 17s 3ms/step - loss: 0.0671 - accuracy: 0.9752
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0674 - accuracy: 0.9749
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0660 - accuracy: 0.9755
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0646 - accuracy: 0.9755
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0650 - accuracy: 0.9758
# [client_3] Encrypting weights...
# Encryption: 0.32s
# [Server] Client 1 update verified (104 chunks)
# Server accepted model from client_3
#
# [client_2] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 16s 3ms/step - loss: 0.0659 - accuracy: 0.9752
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0662 - accuracy: 0.9754
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0659 - accuracy: 0.9753
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0639 - accuracy: 0.9758
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0633 - accuracy: 0.9760
# [client_2] Encrypting weights...
# Encryption: 0.31s
# [Server] Client 2 update verified (104 chunks)
# Server accepted model from client_2
#
# [client_1] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 17s 3ms/step - loss: 0.0664 - accuracy: 0.9753
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0662 - accuracy: 0.9753
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0655 - accuracy: 0.9756
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0647 - accuracy: 0.9760
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0635 - accuracy: 0.9762
# [client_1] Encrypting weights...
# Encryption: 0.32s
# [Server] Client 3 update verified (104 chunks)
# Server accepted model from client_1
#
# [SERVER] Secure aggregation (homomorphic weighted sum)...
# [Server] Performing Byzantine-resistant secure weighted aggregation...
# [Server] Aggregation complete (scaling factors: ['0.2500', '0.2500', '0.2500', '0.2500'])
# [Server] Aggregated hash: aa027eaad1f9c92a9d084364b137ec0e...
# Aggregation: 1.95s
#
# [Hash Verification] Verifying aggregated result...
# Aggregated hash verified ✓
#
# [CLIENTS] Decrypting aggregated model for evaluation...
# Final decryption: 1.51s
# 7982/7982 [==============================] - 7s 912us/step
# comm_round: 6 | global_acc: 97.996% | global_precision: 97.484% | global_recall: 98.536% | global_f1: 98.007% | global_mcc: 95.998% | global_cohen_kappa: 0.96 | global_logloss: 4.941% | global_g_mean: 0.98
#
# ======================================================================
# COMMUNICATION ROUND 8/15
# ======================================================================
# [CLIENTS] Decrypting aggregated model...
# [Decryption] Selected parties: [0, 1, 3]
# Decryption: 1.51s
#
# [client_4] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 17s 3ms/step - loss: 0.0609 - accuracy: 0.9771
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0606 - accuracy: 0.9773
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0599 - accuracy: 0.9774
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0591 - accuracy: 0.9779
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0580 - accuracy: 0.9780
# [client_4] Encrypting weights...
# Encryption: 0.32s
# [Server] Client 0 update verified (104 chunks)
# Server accepted model from client_4
#
# [client_2] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 17s 3ms/step - loss: 0.0623 - accuracy: 0.9764
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0613 - accuracy: 0.9765
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0611 - accuracy: 0.9770
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0602 - accuracy: 0.9768
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0589 - accuracy: 0.9777
# [client_2] Encrypting weights...
# Encryption: 0.31s
# [Server] Client 1 update verified (104 chunks)
# Server accepted model from client_2
#
# [client_3] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 16s 3ms/step - loss: 0.0629 - accuracy: 0.9766
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0621 - accuracy: 0.9768
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0616 - accuracy: 0.9765
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0600 - accuracy: 0.9772
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0598 - accuracy: 0.9772
# [client_3] Encrypting weights...
# Encryption: 0.32s
# [Server] Client 2 update verified (104 chunks)
# Server accepted model from client_3
#
# [client_1] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 17s 3ms/step - loss: 0.0621 - accuracy: 0.9767
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0620 - accuracy: 0.9766
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0615 - accuracy: 0.9767
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0614 - accuracy: 0.9767
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0593 - accuracy: 0.9777
# [client_1] Encrypting weights...
# Encryption: 0.32s
# [Server] Client 3 update verified (104 chunks)
# Server accepted model from client_1
#
# [SERVER] Secure aggregation (homomorphic weighted sum)...
# [Server] Performing Byzantine-resistant secure weighted aggregation...
# [Server] Aggregation complete (scaling factors: ['0.2500', '0.2500', '0.2500', '0.2500'])
# [Server] Aggregated hash: 5448c190cc710783194ab159b3c013f9...
# Aggregation: 1.95s
#
# [Hash Verification] Verifying aggregated result...
# Aggregated hash verified ✓
#
# [CLIENTS] Decrypting aggregated model for evaluation...
# Final decryption: 1.53s
# 7982/7982 [==============================] - 7s 920us/step
# comm_round: 7 | global_acc: 98.028% | global_precision: 97.480% | global_recall: 98.604% | global_f1: 98.039% | global_mcc: 96.061% | global_cohen_kappa: 0.961 | global_logloss: 4.252% | global_g_mean: 0.98
#
# ======================================================================
# COMMUNICATION ROUND 9/15
# ======================================================================
# [CLIENTS] Decrypting aggregated model...
# [Decryption] Selected parties: [0, 2, 3]
# Decryption: 1.50s
#
# [client_3] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 17s 3ms/step - loss: 0.0585 - accuracy: 0.9779
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0573 - accuracy: 0.9785
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0561 - accuracy: 0.9786
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0554 - accuracy: 0.9794
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0538 - accuracy: 0.9799
# [client_3] Encrypting weights...
# Encryption: 0.31s
# [Server] Client 0 update verified (104 chunks)
# Server accepted model from client_3
#
# [client_4] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 17s 3ms/step - loss: 0.0570 - accuracy: 0.9792
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0561 - accuracy: 0.9791
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0541 - accuracy: 0.9796
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0542 - accuracy: 0.9800
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0516 - accuracy: 0.9810
# [client_4] Encrypting weights...
# Encryption: 0.32s
# [Server] Client 1 update verified (104 chunks)
# Server accepted model from client_4
#
# [client_2] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 17s 3ms/step - loss: 0.0573 - accuracy: 0.9786
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0564 - accuracy: 0.9788
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0550 - accuracy: 0.9794
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0545 - accuracy: 0.9794
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0537 - accuracy: 0.9799
# [client_2] Encrypting weights...
# Encryption: 0.32s
# [Server] Client 2 update verified (104 chunks)
# Server accepted model from client_2
#
# [client_1] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 17s 3ms/step - loss: 0.0585 - accuracy: 0.9781
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0573 - accuracy: 0.9784
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0551 - accuracy: 0.9798
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0544 - accuracy: 0.9795
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0526 - accuracy: 0.9806
# [client_1] Encrypting weights...
# Encryption: 0.32s
# [Server] Client 3 update verified (104 chunks)
# Server accepted model from client_1
#
# [SERVER] Secure aggregation (homomorphic weighted sum)...
# [Server] Performing Byzantine-resistant secure weighted aggregation...
# [Server] Aggregation complete (scaling factors: ['0.2500', '0.2500', '0.2500', '0.2500'])
# [Server] Aggregated hash: e2def2ae678ea7c903d0d52c783430f0...
# Aggregation: 1.95s
#
# [Hash Verification] Verifying aggregated result...
# Aggregated hash verified ✓
#
# [CLIENTS] Decrypting aggregated model for evaluation...
# Final decryption: 1.51s
# 7982/7982 [==============================] - 7s 921us/step
# comm_round: 8 | global_acc: 98.922% | global_precision: 98.810% | global_recall: 99.036% | global_f1: 98.923% | global_mcc: 97.844% | global_cohen_kappa: 0.978 | global_logloss: 3.392% | global_g_mean: 0.989
#
# ======================================================================
# COMMUNICATION ROUND 10/15
# ======================================================================
# [CLIENTS] Decrypting aggregated model...
# [Decryption] Selected parties: [0, 1, 2]
# Decryption: 1.50s
#
# [client_4] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 17s 3ms/step - loss: 0.0509 - accuracy: 0.9814
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0498 - accuracy: 0.9814
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0489 - accuracy: 0.9821
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0486 - accuracy: 0.9823
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0476 - accuracy: 0.9825
# [client_4] Encrypting weights...
# Encryption: 0.31s
# [Server] Client 0 update verified (104 chunks)
# Server accepted model from client_4
#
# [client_1] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 17s 3ms/step - loss: 0.0512 - accuracy: 0.9810
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0504 - accuracy: 0.9818
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0497 - accuracy: 0.9816
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0489 - accuracy: 0.9825
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0477 - accuracy: 0.9829
# [client_1] Encrypting weights...
# Encryption: 0.31s
# [Server] Client 1 update verified (104 chunks)
# Server accepted model from client_1
#
# [client_3] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 16s 3ms/step - loss: 0.0515 - accuracy: 0.9808
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0512 - accuracy: 0.9815
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0512 - accuracy: 0.9815
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0506 - accuracy: 0.9814
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0490 - accuracy: 0.9818
# [client_3] Encrypting weights...
# Encryption: 0.31s
# [Server] Client 2 update verified (104 chunks)
# Server accepted model from client_3
#
# [client_2] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 17s 3ms/step - loss: 0.0523 - accuracy: 0.9804
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0512 - accuracy: 0.9812
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0501 - accuracy: 0.9817
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0497 - accuracy: 0.9818
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0476 - accuracy: 0.9824
# [client_2] Encrypting weights...
# Encryption: 0.32s
# [Server] Client 3 update verified (104 chunks)
# Server accepted model from client_2
#
# [SERVER] Secure aggregation (homomorphic weighted sum)...
# [Server] Performing Byzantine-resistant secure weighted aggregation...
# [Server] Aggregation complete (scaling factors: ['0.2500', '0.2500', '0.2500', '0.2500'])
# [Server] Aggregated hash: a89f0a5f9de3d76cd7fdacd91db25488...
# Aggregation: 1.95s
#
# [Hash Verification] Verifying aggregated result...
# Aggregated hash verified ✓
#
# [CLIENTS] Decrypting aggregated model for evaluation...
# Final decryption: 1.52s
# 7982/7982 [==============================] - 8s 925us/step
# comm_round: 9 | global_acc: 98.899% | global_precision: 98.813% | global_recall: 98.986% | global_f1: 98.900% | global_mcc: 97.797% | global_cohen_kappa: 0.978 | global_logloss: 3.261% | global_g_mean: 0.989
#
# ======================================================================
# COMMUNICATION ROUND 11/15
# ======================================================================
# [CLIENTS] Decrypting aggregated model...
# [Decryption] Selected parties: [1, 2, 3]
# Decryption: 1.49s
#
# [client_2] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 17s 3ms/step - loss: 0.0472 - accuracy: 0.9829
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0469 - accuracy: 0.9831
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0465 - accuracy: 0.9829
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0464 - accuracy: 0.9831
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0443 - accuracy: 0.9839
# [client_2] Encrypting weights...
# Encryption: 0.31s
# [Server] Client 0 update verified (104 chunks)
# Server accepted model from client_2
#
# [client_1] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 17s 3ms/step - loss: 0.0474 - accuracy: 0.9832
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0468 - accuracy: 0.9831
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0457 - accuracy: 0.9833
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0448 - accuracy: 0.9838
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0445 - accuracy: 0.9840
# [client_1] Encrypting weights...
# Encryption: 0.32s
# [Server] Client 1 update verified (104 chunks)
# Server accepted model from client_1
#
# [client_3] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 16s 3ms/step - loss: 0.0476 - accuracy: 0.9827
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0476 - accuracy: 0.9829
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0466 - accuracy: 0.9831
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0448 - accuracy: 0.9839
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0457 - accuracy: 0.9836
# [client_3] Encrypting weights...
# Encryption: 0.32s
# [Server] Client 2 update verified (104 chunks)
# Server accepted model from client_3
#
# [client_4] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 17s 3ms/step - loss: 0.0467 - accuracy: 0.9829
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0458 - accuracy: 0.9833
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0454 - accuracy: 0.9838
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0439 - accuracy: 0.9840
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0443 - accuracy: 0.9842
# [client_4] Encrypting weights...
# Encryption: 0.32s
# [Server] Client 3 update verified (104 chunks)
# Server accepted model from client_4
#
# [SERVER] Secure aggregation (homomorphic weighted sum)...
# [Server] Performing Byzantine-resistant secure weighted aggregation...
# [Server] Aggregation complete (scaling factors: ['0.2500', '0.2500', '0.2500', '0.2500'])
# [Server] Aggregated hash: 918406a3e798945aa65ad2bdf6a8d99c...
# Aggregation: 1.95s
#
# ...
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0423 - accuracy: 0.9847
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0412 - accuracy: 0.9855
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0412 - accuracy: 0.9855
# [client_1] Encrypting weights...
# Encryption: 0.32s
# [Server] Client 0 update verified (104 chunks)
# Server accepted model from client_1
#
# [client_2] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 16s 3ms/step - loss: 0.0446 - accuracy: 0.9840
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0436 - accuracy: 0.9844
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0442 - accuracy: 0.9839
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0428 - accuracy: 0.9849
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0422 - accuracy: 0.9848
# [client_2] Encrypting weights...
# Encryption: 0.31s
# [Server] Client 1 update verified (104 chunks)
# Server accepted model from client_2
#
# [client_3] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 17s 3ms/step - loss: 0.0446 - accuracy: 0.9845
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0438 - accuracy: 0.9845
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0426 - accuracy: 0.9847
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0431 - accuracy: 0.9845
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0423 - accuracy: 0.9850
# [client_3] Encrypting weights...
# Encryption: 0.32s
# [Server] Client 2 update verified (104 chunks)
# Server accepted model from client_3
#
# [client_4] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 17s 3ms/step - loss: 0.0432 - accuracy: 0.9845
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0419 - accuracy: 0.9849
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0425 - accuracy: 0.9848
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0417 - accuracy: 0.9848
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0417 - accuracy: 0.9852
# [client_4] Encrypting weights...
# Encryption: 0.32s
# [Server] Client 3 update verified (104 chunks)
# Server accepted model from client_4
#
# [SERVER] Secure aggregation (homomorphic weighted sum)...
# [Server] Performing Byzantine-resistant secure weighted aggregation...
# [Server] Aggregation complete (scaling factors: ['0.2500', '0.2500', '0.2500', '0.2500'])
# [Server] Aggregated hash: 6bf91aee8a954ec4c0d9a17c996ec7d0...
# Aggregation: 1.95s
#
# [Hash Verification] Verifying aggregated result...
# Aggregated hash verified ✓
#
# [CLIENTS] Decrypting aggregated model for evaluation...
# Final decryption: 1.50s
# 7982/7982 [==============================] - 8s 926us/step
# comm_round: 11 | global_acc: 99.010% | global_precision: 98.926% | global_recall: 99.096% | global_f1: 99.011% | global_mcc: 98.021% | global_cohen_kappa: 0.98 | global_logloss: 2.760% | global_g_mean: 0.99
#
# ======================================================================
# COMMUNICATION ROUND 13/15
# ======================================================================
# [CLIENTS] Decrypting aggregated model...
# [Decryption] Selected parties: [0, 1, 3]
# Decryption: 1.52s
#
# [client_3] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 17s 3ms/step - loss: 0.0419 - accuracy: 0.9853
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0411 - accuracy: 0.9853
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0411 - accuracy: 0.9855
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0404 - accuracy: 0.9856
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0408 - accuracy: 0.9858
# [client_3] Encrypting weights...
# Encryption: 0.32s
# [Server] Client 0 update verified (104 chunks)
# Server accepted model from client_3
#
# [client_4] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 17s 3ms/step - loss: 0.0405 - accuracy: 0.9855
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0400 - accuracy: 0.9858
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0397 - accuracy: 0.9858
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0402 - accuracy: 0.9857
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0393 - accuracy: 0.9860
# [client_4] Encrypting weights...
# Encryption: 0.32s
# [Server] Client 1 update verified (104 chunks)
# Server accepted model from client_4
#
# [client_2] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 17s 3ms/step - loss: 0.0417 - accuracy: 0.9851
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0413 - accuracy: 0.9856
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0415 - accuracy: 0.9854
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0409 - accuracy: 0.9860
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0414 - accuracy: 0.9856
# [client_2] Encrypting weights...
# Encryption: 0.31s
# [Server] Client 2 update verified (104 chunks)
# Server accepted model from client_2
#
# [client_1] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 17s 3ms/step - loss: 0.0407 - accuracy: 0.9858
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0407 - accuracy: 0.9857
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0400 - accuracy: 0.9860
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0389 - accuracy: 0.9865
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0398 - accuracy: 0.9862
# [client_1] Encrypting weights...
# Encryption: 0.31s
# [Server] Client 3 update verified (104 chunks)
# Server accepted model from client_1
#
# [SERVER] Secure aggregation (homomorphic weighted sum)...
# [Server] Performing Byzantine-resistant secure weighted aggregation...
# [Server] Aggregation complete (scaling factors: ['0.2500', '0.2500', '0.2500', '0.2500'])
# [Server] Aggregated hash: 0962436f6cba54b36025884c868ed39e...
# Aggregation: 1.96s
#
# [Hash Verification] Verifying aggregated result...
# Aggregated hash verified ✓
#
# [CLIENTS] Decrypting aggregated model for evaluation...
# Final decryption: 1.49s
# 7982/7982 [==============================] - 7s 910us/step
# comm_round: 12 | global_acc: 99.036% | global_precision: 98.891% | global_recall: 99.184% | global_f1: 99.037% | global_mcc: 98.072% | global_cohen_kappa: 0.981 | global_logloss: 2.683% | global_g_mean: 0.99
#
# ======================================================================
# COMMUNICATION ROUND 14/15
# ======================================================================
# [CLIENTS] Decrypting aggregated model...
# [Decryption] Selected parties: [0, 1, 3]
# Decryption: 1.49s
#
# [client_3] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 17s 3ms/step - loss: 0.0398 - accuracy: 0.9860
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0404 - accuracy: 0.9861
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0390 - accuracy: 0.9863
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0389 - accuracy: 0.9866
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0390 - accuracy: 0.9863
# [client_3] Encrypting weights...
# Encryption: 0.32s
# [Server] Client 0 update verified (104 chunks)
# Server accepted model from client_3
#
# [client_2] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 17s 3ms/step - loss: 0.0404 - accuracy: 0.9860
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0395 - accuracy: 0.9862
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0394 - accuracy: 0.9863
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0386 - accuracy: 0.9865
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0389 - accuracy: 0.9866
# [client_2] Encrypting weights...
# Encryption: 0.31s
# [Server] Client 1 update verified (104 chunks)
# Server accepted model from client_2
#
# [client_1] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 17s 3ms/step - loss: 0.0388 - accuracy: 0.9867
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0377 - accuracy: 0.9869
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0389 - accuracy: 0.9866
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0379 - accuracy: 0.9866
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0377 - accuracy: 0.9872
# [client_1] Encrypting weights...
# Encryption: 0.32s
# [Server] Client 2 update verified (104 chunks)
# Server accepted model from client_1
#
# [client_4] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 17s 3ms/step - loss: 0.0388 - accuracy: 0.9863
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0384 - accuracy: 0.9863
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0387 - accuracy: 0.9862
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0386 - accuracy: 0.9863
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0375 - accuracy: 0.9869
# [client_4] Encrypting weights...
# Encryption: 0.32s
# [Server] Client 3 update verified (104 chunks)
# Server accepted model from client_4
#
# [SERVER] Secure aggregation (homomorphic weighted sum)...
# [Server] Performing Byzantine-resistant secure weighted aggregation...
# [Server] Aggregation complete (scaling factors: ['0.2500', '0.2500', '0.2500', '0.2500'])
# [Server] Aggregated hash: 2fa51253e7b0fe30c2ed3ef2795d78f0...
# Aggregation: 1.94s
#
# [Hash Verification] Verifying aggregated result...
# Aggregated hash verified ✓
#
# [CLIENTS] Decrypting aggregated model for evaluation...
# Final decryption: 1.48s
# 7982/7982 [==============================] - 7s 915us/step
# comm_round: 13 | global_acc: 99.076% | global_precision: 99.026% | global_recall: 99.126% | global_f1: 99.076% | global_mcc: 98.151% | global_cohen_kappa: 0.982 | global_logloss: 2.587% | global_g_mean: 0.991
#
# ======================================================================
# COMMUNICATION ROUND 15/15
# ======================================================================
# [CLIENTS] Decrypting aggregated model...
# [Decryption] Selected parties: [0, 1, 2]
# Decryption: 1.49s
#
# [client_3] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 17s 3ms/step - loss: 0.0381 - accuracy: 0.9867
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0374 - accuracy: 0.9868
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0379 - accuracy: 0.9870
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0384 - accuracy: 0.9867
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0370 - accuracy: 0.9872
# [client_3] Encrypting weights...
# Encryption: 0.32s
# [Server] Client 0 update verified (104 chunks)
# Server accepted model from client_3
#
# [client_4] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 17s 3ms/step - loss: 0.0373 - accuracy: 0.9873
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0375 - accuracy: 0.9870
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0365 - accuracy: 0.9871
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0367 - accuracy: 0.9873
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0362 - accuracy: 0.9877
# [client_4] Encrypting weights...
# Encryption: 0.32s
# [Server] Client 1 update verified (104 chunks)
# Server accepted model from client_4
#
# [client_2] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 17s 3ms/step - loss: 0.0375 - accuracy: 0.9870
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0386 - accuracy: 0.9866
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0373 - accuracy: 0.9871
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0381 - accuracy: 0.9866
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0375 - accuracy: 0.9870
# [client_2] Encrypting weights...
# Encryption: 0.32s
# [Server] Client 2 update verified (104 chunks)
# Server accepted model from client_2
#
# [client_1] Local training...
# Epoch 1/5
# 4656/4656 [==============================] - 17s 3ms/step - loss: 0.0368 - accuracy: 0.9872
# Epoch 2/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0371 - accuracy: 0.9871
# Epoch 3/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0366 - accuracy: 0.9872
# Epoch 4/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0368 - accuracy: 0.9874
# Epoch 5/5
# 4656/4656 [==============================] - 14s 3ms/step - loss: 0.0366 - accuracy: 0.9874
# [client_1] Encrypting weights...
# Encryption: 0.32s
# [Server] Client 3 update verified (104 chunks)
# Server accepted model from client_1
#
# [SERVER] Secure aggregation (homomorphic weighted sum)...
# [Server] Performing Byzantine-resistant secure weighted aggregation...
# [Server] Aggregation complete (scaling factors: ['0.2500', '0.2500', '0.2500', '0.2500'])
# [Server] Aggregated hash: 83a294945d9cf62bba21fb0d09302b2a...
# Aggregation: 1.94s
#
# [Hash Verification] Verifying aggregated result...
# Aggregated hash verified ✓
#
# [CLIENTS] Decrypting aggregated model for evaluation...
# Final decryption: 1.49s
# 7982/7982 [==============================] - 7s 909us/step
# comm_round: 14 | global_acc: 99.038% | global_precision: 99.001% | global_recall: 99.077% | global_f1: 99.039% | global_mcc: 98.077% | global_cohen_kappa: 0.981 | global_logloss: 2.592% | global_g_mean: 0.99
#
# ======================================================================
# FINAL DKG TRUE THRESHOLD FEDERATED LEARNING SUMMARY
# ======================================================================
# Total Communication Overhead : 4697.89 MB
# Total Computation Time       : 4490.35s
# Total Encryption Time        : 18.99s
# Total Decryption Time        : 43.27s
# Total Aggregation Time       : 29.20s
# Avg Communication per Round  : 313.19 MB
# Avg Computation per Round    : 299.36s
# 7982/7982 [==============================] - 7s 925us/step
# Final Results | acc: 99.038% | prec: 99.001% | recall: 99.077% | f1: 99.039% | mcc: 98.077% | kappa: 0.981 | logloss: 2.592% | g_mean: 0.99
#
# ======================================================================
# CENTRALISED TRAINING FOR COMPARISON
# ======================================================================
# /usr/local/lib/python3.8/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 1165/1165 [==============================] - 7s 3ms/step - loss: 0.1145 - accuracy: 0.9530
# Centralised training time: 7.74s
# 7982/7982 [==============================] - 8s 917us/step
# Centralised | acc: 95.992% | prec: 93.580% | recall: 98.759% | f1: 96.100% | mcc: 92.125% | kappa: 0.92 | logloss: 8.454% | g_mean: 0.96
#
# ======================================================================
# ALL TRAINING COMPLETE!
# ======================================================================
#
# No malicious clients detected during training

# %%
#pip install shap
